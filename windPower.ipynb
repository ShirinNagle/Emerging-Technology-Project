# %%
import pandas
df = pandas.read_csv('powerproduction.csv')
print(df)
# Out:
#       speed  power
# 0     0.000    0.0
# 1     0.125    0.0
# 2     0.150    0.0
# 3     0.225    0.0
# 4     0.275    0.0
# ..      ...    ...
# 495  24.775    0.0
# 496  24.850    0.0
# 497  24.875    0.0
# 498  24.950    0.0
# 499  25.000    0.0
#
# [500 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
df.plot(y='speed', x='power')
df.plot(x='speed', y='power')

# %%
df.plot.scatter(y='speed', x='power')
df.plot.scatter(x='speed', y='power')

# %%
df = pandas.read_csv('powerproduction.csv')
print(df)
# Out:
#      number   speed  power
# 0         1   0.000    0.0
# 1         2   0.125    0.0
# 2         3   0.150    0.0
# 3         4   0.225    0.0
# 4         5   0.275    0.0
# ..      ...     ...    ...
# 495     496  24.775    0.0
# 496     497  24.850    0.0
# 497     498  24.875    0.0
# 498     499  24.950    0.0
# 499     500  25.000    0.0
#
# [500 rows x 3 columns]

# %%
df.plot.scatter(y='speed', x='number')
df.plot.scatter(x='number', y='power')

# %%
df.plot.scatter(y='number', x='speed')
df.plot.scatter(x='power', y='number')
